# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"cleaned_global_water_consumption.csv")
data
# Out:
#        Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0    Argentina  2000                                      481.490000
# 1    Argentina  2001                                      455.063000
# 2    Argentina  2002                                      482.749231
# 3    Argentina  2003                                      452.660000
# 4    Argentina  2004                                      634.566000
# ..         ...   ...                                             ...
# 495        USA  2020                                      418.097000
# 496        USA  2021                                      572.094000
# 497        USA  2022                                      440.978000
# 498        USA  2023                                      566.865000
# 499        USA  2024                                      249.485000
#
#      Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# 0                               235.431429                   48.550000
# 1                               299.551000                   48.465000
# 2                               340.124615                   50.375385
# 3                               326.756667                   49.086667
# 4                               230.346000                   38.670000
# ..                                     ...                         ...
# 495                             292.970000                   47.448000
# 496                             275.978000                   46.195000
# 497                             292.039000                   54.810000
# 498                             261.197500                   62.945000
# 499                             186.374000                   51.386000
#
#      Industrial Water Use (%)  Household Water Use (%)  \
# 0                   20.844286                30.100000
# 1                   26.943000                22.550000
# 2                   29.042308                23.349231
# 3                   30.476000                24.440000
# 4                   36.670000                23.924000
# ..                        ...                      ...
# 495                 25.266000                27.538000
# 496                 32.223000                26.720000
# 497                 30.918000                22.638000
# 498                 25.207500                21.632500
# 499                 24.769000                27.677000
#
#      Rainfall Impact (Annual Precipitation in mm)  \
# 0                                     1288.698571
# 1                                     1371.729000
# 2                                     1590.305385
# 3                                     1816.012667
# 4                                      815.998000
# ..                                            ...
# 495                                   1510.662000
# 496                                    754.615000
# 497                                   2119.898000
# 498                                   1439.155000
# 499                                   1771.199000
#
#      Groundwater Depletion Rate (%) Water Scarcity Level
# 0                          3.255714             Moderate
# 1                          3.120000             Moderate
# 2                          2.733846             Moderate
# 3                          2.708000             Moderate
# 4                          1.902000             Moderate
# ..                              ...                  ...
# 495                        2.431000             Moderate
# 496                        2.628000             Moderate
# 497                        2.871000             Moderate
# 498                        1.597500             Moderate
# 499                        1.638000                 High
#
# [500 rows x 10 columns]

# %%
data["Country"].unique()
# Out:
# array(['Argentina', 'Australia', 'Brazil', 'Canada', 'China', 'France',
#        'Germany', 'India', 'Indonesia', 'Italy', 'Japan', 'Mexico',
#        'Russia', 'Saudi Arabia', 'South Africa', 'South Korea', 'Spain',
#        'Turkey', 'UK', 'USA'], dtype=object)

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
data.head()
# Out:
#      Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0  Argentina  2000                                      481.490000
# 1  Argentina  2001                                      455.063000
# 2  Argentina  2002                                      482.749231
# 3  Argentina  2003                                      452.660000
# 4  Argentina  2004                                      634.566000
#
#    Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# 0                             235.431429                   48.550000
# 1                             299.551000                   48.465000
# 2                             340.124615                   50.375385
# 3                             326.756667                   49.086667
# 4                             230.346000                   38.670000
#
#    Industrial Water Use (%)  Household Water Use (%)  \
# 0                 20.844286                30.100000
# 1                 26.943000                22.550000
# 2                 29.042308                23.349231
# 3                 30.476000                24.440000
# 4                 36.670000                23.924000
#
#    Rainfall Impact (Annual Precipitation in mm)  \
# 0                                   1288.698571
# 1                                   1371.729000
# 2                                   1590.305385
# 3                                   1816.012667
# 4                                    815.998000
#
#    Groundwater Depletion Rate (%) Water Scarcity Level
# 0                        3.255714             Moderate
# 1                        3.120000             Moderate
# 2                        2.733846             Moderate
# 3                        2.708000             Moderate
# 4                        1.902000             Moderate

# %%
data.tail()
# Out:
#     Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 495     USA  2020                                         418.097
# 496     USA  2021                                         572.094
# 497     USA  2022                                         440.978
# 498     USA  2023                                         566.865
# 499     USA  2024                                         249.485
#
#      Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# 495                               292.9700                      47.448
# 496                               275.9780                      46.195
# 497                               292.0390                      54.810
# 498                               261.1975                      62.945
# 499                               186.3740                      51.386
#
#      Industrial Water Use (%)  Household Water Use (%)  \
# 495                   25.2660                  27.5380
# 496                   32.2230                  26.7200
# 497                   30.9180                  22.6380
# 498                   25.2075                  21.6325
# 499                   24.7690                  27.6770
#
#      Rainfall Impact (Annual Precipitation in mm)  \
# 495                                      1510.662
# 496                                       754.615
# 497                                      2119.898
# 498                                      1439.155
# 499                                      1771.199
#
#      Groundwater Depletion Rate (%) Water Scarcity Level
# 495                          2.4310             Moderate
# 496                          2.6280             Moderate
# 497                          2.8710             Moderate
# 498                          1.5975             Moderate
# 499                          1.6380                 High

# %%
data.isna().any()
# Out:
# Country                                           False
# Year                                              False
# Total Water Consumption (Billion Cubic Meters)    False
# Per Capita Water Use (Liters per Day)             False
# Agricultural Water Use (%)                        False
# Industrial Water Use (%)                          False
# Household Water Use (%)                           False
# Rainfall Impact (Annual Precipitation in mm)      False
# Groundwater Depletion Rate (%)                    False
# Water Scarcity Level                              False
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Country                                         500 non-null    object
#  1   Year                                            500 non-null    int64
#  2   Total Water Consumption (Billion Cubic Meters)  500 non-null    float64
#  3   Per Capita Water Use (Liters per Day)           500 non-null    float64
#  4   Agricultural Water Use (%)                      500 non-null    float64
#  5   Industrial Water Use (%)                        500 non-null    float64
#  6   Household Water Use (%)                         500 non-null    float64
#  7   Rainfall Impact (Annual Precipitation in mm)    500 non-null    float64
#  8   Groundwater Depletion Rate (%)                  500 non-null    float64
#  9   Water Scarcity Level                            500 non-null    object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
data.duplicated().any()
# Out:
# np.False_

# %%
data.describe()
# Out:
#               Year  Total Water Consumption (Billion Cubic Meters)  \
# count   500.000000                                      500.000000
# mean   2012.000000                                      501.224430
# std       7.218324                                       96.078937
# min    2000.000000                                      129.636667
# 25%    2006.000000                                      441.447385
# 50%    2012.000000                                      502.197154
# 75%    2018.000000                                      563.849594
# max    2024.000000                                      798.418000
#
#        Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# count                             500.000000                  500.000000
# mean                              276.004782                   50.180829
# std                                42.669593                    5.566886
# min                               111.708333                   28.905000
# 25%                               250.225406                   46.513611
# 50%                               276.430556                   50.318482
# 75%                               300.221750                   54.061964
# max                               404.350000                   66.520000
#
#        Industrial Water Use (%)  Household Water Use (%)  \
# count                500.000000               500.000000
# mean                  27.792837                24.832515
# std                    4.361660                 2.956135
# min                   13.276667                13.668333
# 25%                   25.018000                23.015355
# 50%                   27.648539                25.071944
# 75%                   30.698333                26.720167
# max                   43.583333                34.202000
#
#        Rainfall Impact (Annual Precipitation in mm)  \
# count                                    500.000000
# mean                                    1544.824300
# std                                      292.786579
# min                                      700.230000
# 25%                                     1353.734583
# 50%                                     1537.537724
# 75%                                     1746.402425
# max                                     2533.678000
#
#        Groundwater Depletion Rate (%)
# count                      500.000000
# mean                         2.573037
# std                          0.480630
# min                          1.300000
# 25%                          2.235000
# 50%                          2.555778
# 75%                          2.887202
# max                          4.322000

# %% [markdown]
# ## VISUALISING DATA BY MATPLOTLIB

# %%
data1=data.drop(['Country','Year','Total Water Consumption (Billion Cubic Meters)','Per Capita Water Use (Liters per Day)','Agricultural Water Use (%)','Industrial Water Use (%)','Household Water Use (%)','Rainfall Impact (Annual Precipitation in mm)','Groundwater Depletion Rate (%)'],axis=1)
data1
# Out:
#     Water Scarcity Level
# 0               Moderate
# 1               Moderate
# 2               Moderate
# 3               Moderate
# 4               Moderate
# ..                   ...
# 495             Moderate
# 496             Moderate
# 497             Moderate
# 498             Moderate
# 499                 High
#
# [500 rows x 1 columns]

# %%
plt.figure(figsize=(12,6))
plt.plot(data['Water Scarcity Level'],data['Groundwater Depletion Rate (%)'],color='#800000',label='Groundwater Depletion Rate (%)',marker='s')
plt.xlabel('Water Scarcity Level')
plt.ylabel('Groundwater Depletion Rate(%)')
plt.title('Water Rate')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
obj = LabelEncoder()

# %%
data["Country"]=obj.fit_transform(data["Country"])

# %%
data
# Out:
#      Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0          0  2000                                      481.490000
# 1          0  2001                                      455.063000
# 2          0  2002                                      482.749231
# 3          0  2003                                      452.660000
# 4          0  2004                                      634.566000
# ..       ...   ...                                             ...
# 495       19  2020                                      418.097000
# 496       19  2021                                      572.094000
# 497       19  2022                                      440.978000
# 498       19  2023                                      566.865000
# 499       19  2024                                      249.485000
#
#      Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# 0                               235.431429                   48.550000
# 1                               299.551000                   48.465000
# 2                               340.124615                   50.375385
# 3                               326.756667                   49.086667
# 4                               230.346000                   38.670000
# ..                                     ...                         ...
# 495                             292.970000                   47.448000
# 496                             275.978000                   46.195000
# 497                             292.039000                   54.810000
# 498                             261.197500                   62.945000
# 499                             186.374000                   51.386000
#
#      Industrial Water Use (%)  Household Water Use (%)  \
# 0                   20.844286                30.100000
# 1                   26.943000                22.550000
# 2                   29.042308                23.349231
# 3                   30.476000                24.440000
# 4                   36.670000                23.924000
# ..                        ...                      ...
# 495                 25.266000                27.538000
# 496                 32.223000                26.720000
# 497                 30.918000                22.638000
# 498                 25.207500                21.632500
# 499                 24.769000                27.677000
#
#      Rainfall Impact (Annual Precipitation in mm)  \
# 0                                     1288.698571
# 1                                     1371.729000
# 2                                     1590.305385
# 3                                     1816.012667
# 4                                      815.998000
# ..                                            ...
# 495                                   1510.662000
# 496                                    754.615000
# 497                                   2119.898000
# 498                                   1439.155000
# 499                                   1771.199000
#
#      Groundwater Depletion Rate (%) Water Scarcity Level
# 0                          3.255714             Moderate
# 1                          3.120000             Moderate
# 2                          2.733846             Moderate
# 3                          2.708000             Moderate
# 4                          1.902000             Moderate
# ..                              ...                  ...
# 495                        2.431000             Moderate
# 496                        2.628000             Moderate
# 497                        2.871000             Moderate
# 498                        1.597500             Moderate
# 499                        1.638000                 High
#
# [500 rows x 10 columns]

# %%
x=data.drop(['Water Scarcity Level'],axis=1)
y=data['Water Scarcity Level']

# %%
y
# Out:
# 0      Moderate
# 1      Moderate
# 2      Moderate
# 3      Moderate
# 4      Moderate
#          ...
# 495    Moderate
# 496    Moderate
# 497    Moderate
# 498    Moderate
# 499        High
# Name: Water Scarcity Level, Length: 500, dtype: object

# %%
x
# Out:
#      Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0          0  2000                                      481.490000
# 1          0  2001                                      455.063000
# 2          0  2002                                      482.749231
# 3          0  2003                                      452.660000
# 4          0  2004                                      634.566000
# ..       ...   ...                                             ...
# 495       19  2020                                      418.097000
# 496       19  2021                                      572.094000
# 497       19  2022                                      440.978000
# 498       19  2023                                      566.865000
# 499       19  2024                                      249.485000
#
#      Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# 0                               235.431429                   48.550000
# 1                               299.551000                   48.465000
# 2                               340.124615                   50.375385
# 3                               326.756667                   49.086667
# 4                               230.346000                   38.670000
# ..                                     ...                         ...
# 495                             292.970000                   47.448000
# 496                             275.978000                   46.195000
# 497                             292.039000                   54.810000
# 498                             261.197500                   62.945000
# 499                             186.374000                   51.386000
#
#      Industrial Water Use (%)  Household Water Use (%)  \
# 0                   20.844286                30.100000
# 1                   26.943000                22.550000
# 2                   29.042308                23.349231
# 3                   30.476000                24.440000
# 4                   36.670000                23.924000
# ..                        ...                      ...
# 495                 25.266000                27.538000
# 496                 32.223000                26.720000
# 497                 30.918000                22.638000
# 498                 25.207500                21.632500
# 499                 24.769000                27.677000
#
#      Rainfall Impact (Annual Precipitation in mm)  \
# 0                                     1288.698571
# 1                                     1371.729000
# 2                                     1590.305385
# 3                                     1816.012667
# 4                                      815.998000
# ..                                            ...
# 495                                   1510.662000
# 496                                    754.615000
# 497                                   2119.898000
# 498                                   1439.155000
# 499                                   1771.199000
#
#      Groundwater Depletion Rate (%)
# 0                          3.255714
# 1                          3.120000
# 2                          2.733846
# 3                          2.708000
# 4                          1.902000
# ..                              ...
# 495                        2.431000
# 496                        2.628000
# 497                        2.871000
# 498                        1.597500
# 499                        1.638000
#
# [500 rows x 9 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
ytrain
# Out:
# 5      Moderate
# 116    Moderate
# 45     Moderate
# 16     Moderate
# 462    Moderate
#          ...
# 106    Moderate
# 270    Moderate
# 348    Moderate
# 435    Moderate
# 102    Moderate
# Name: Water Scarcity Level, Length: 350, dtype: object

# %%
xtrain
# Out:
#      Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 5          0  2005                                      458.077000
# 116        4  2016                                      524.209333
# 45         1  2020                                      484.798750
# 16         0  2016                                      467.318095
# 462       18  2012                                      583.028000
# ..       ...   ...                                             ...
# 106        4  2006                                      455.554546
# 270       10  2020                                      211.816667
# 348       13  2023                                      604.980000
# 435       17  2010                                      559.448333
# 102        4  2002                                      440.705385
#
#      Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# 5                               265.012000                   59.834000
# 116                             289.594667                   51.647333
# 45                              292.505000                   48.473750
# 16                              322.053809                   49.361905
# 462                             256.860000                   55.234000
# ..                                     ...                         ...
# 106                             296.594545                   45.900909
# 270                             275.443333                   63.690000
# 348                             268.150000                   46.628000
# 435                             294.835000                   49.486667
# 102                             236.366154                   48.579231
#
#      Industrial Water Use (%)  Household Water Use (%)  \
# 5                   29.288000                22.649000
# 116                 32.768000                28.114667
# 45                  23.680000                27.546250
# 16                  28.402381                22.307619
# 462                 25.092000                28.568000
# ..                        ...                      ...
# 106                 23.290000                27.984545
# 270                 25.293333                20.760000
# 348                 34.144000                23.651000
# 435                 26.298333                17.395000
# 102                 30.263077                26.956923
#
#      Rainfall Impact (Annual Precipitation in mm)  \
# 5                                     1826.293000
# 116                                   1755.536667
# 45                                    1549.618750
# 16                                    1730.010000
# 462                                   1908.753000
# ..                                            ...
# 106                                   1801.888182
# 270                                   2151.440000
# 348                                   1506.594000
# 435                                   1073.235000
# 102                                   1538.954615
#
#      Groundwater Depletion Rate (%)
# 5                          2.724000
# 116                        3.066000
# 45                         2.380000
# 16                         2.642857
# 462                        2.570000
# ..                              ...
# 106                        2.977273
# 270                        1.966667
# 348                        2.485000
# 435                        2.630000
# 102                        2.877692
#
# [350 rows x 9 columns]

# %% [markdown]
# # MODEL FITTING

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(xtrain,ytrain)
print("Model trained Successfully")
# Out:
# Model trained Successfully

# %%
poi=model.predict(xtest)
poi
# Out:
# array(['Moderate', 'Low', 'Moderate', 'Moderate', 'Low', 'Moderate',
#        'Moderate', 'Moderate', 'Moderate', 'Low', 'Moderate', 'Moderate',
#        'High', 'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Moderate',
#        'Low', 'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Low',
#        'Low', 'Moderate', 'Moderate', 'Moderate', 'Low', 'Moderate',
#        'Moderate', 'Low', 'Moderate', 'Moderate', 'Low', 'Moderate',
#        'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Moderate',
#        'Moderate', 'High', 'Low', 'Moderate', 'Low', 'Moderate', 'Low',
#        'Low', 'Moderate', 'Moderate', 'Low', 'Moderate', 'Moderate',
#        'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Moderate',
#        'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Low',
#        'Moderate', 'Low', 'Moderate', 'Moderate', 'Moderate', 'Low',
#        'Moderate', 'High', 'Moderate', 'Low', 'Moderate', 'Moderate',
#        'Moderate', 'Low', 'Moderate', 'Moderate', 'Moderate', 'Moderate',
#        'Moderate', 'Moderate', 'Low', 'Low', 'Low', 'Moderate', 'Low',
#        'Moderate', 'Moderate', 'Moderate', 'Low', 'Low', 'Moderate',
#        'Low', 'Moderate', 'Low', 'Moderate', 'Low', 'Moderate',
#        'Moderate', 'Moderate', 'Low', 'Moderate', 'Moderate', 'High',
#        'Moderate', 'Moderate', 'Low', 'Moderate', 'Low', 'Moderate',
#        'Low', 'Low', 'Moderate', 'Moderate', 'Moderate', 'Low',
#        'Moderate', 'Moderate', 'Low', 'Moderate', 'Moderate', 'Moderate',
#        'Low', 'Moderate', 'Moderate', 'Low', 'Moderate', 'Moderate',
#        'Moderate', 'Low', 'Moderate', 'Moderate', 'Moderate', 'Low',
#        'Moderate', 'Moderate', 'Moderate', 'High', 'Low', 'Low',
#        'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Low', 'Moderate'],
#       dtype=object)

# %%
Logistictrain=model.score(xtrain,ytrain)*100
Logistictrain
# Out:
# 97.42857142857143

# %%
Logistictest=model.score(xtest,ytest)*100
Logistictest
# Out:
# 92.0

# %% [markdown]
# ## DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier()
model2.fit(xtrain,ytrain)
print("Model trained Successfully")
# Out:
# Model trained Successfully

# %%
DecisionTreetrain=model2.score(xtrain,ytrain)*100
DecisionTreetrain
# Out:
# 100.0

# %%
DecisionTreetest=model2.score(xtest,ytest)*100
DecisionTreetest
# Out:
# 95.33333333333334

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
model3=RandomForestClassifier(n_estimators=100)
model3.fit(xtrain,ytrain)
print("Model trained Successfully")
# Out:
# Model trained Successfully

# %%
RandomForesttrain=model3.score(xtrain,ytrain)*100
RandomForesttrain
# Out:
# 100.0

# %%
RandomForesttest=model3.score(xtest,ytest)*100
RandomForesttest
# Out:
# 94.0

# %% [markdown]
# ## AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
model4=AdaBoostClassifier(n_estimators=50)
model4.fit(xtrain,ytrain)
print("Model trained Successfully")
# Out:
# Model trained Successfully

# %%
AdaBoosttrain=model4.score(xtrain,ytrain)*100
AdaBoosttrain
# Out:
# 100.0

# %%
AdaBoosttest=model4.score(xtest,ytest)*100
AdaBoosttest
# Out:
# 96.66666666666667

# %% [markdown]
# ## GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
model5=GradientBoostingClassifier(n_estimators=50)
model5.fit(xtrain,ytrain)
print("Model trained Successfully")
# Out:
# Model trained Successfully

# %%
GradientBoostingtrain=model5.score(xtrain,ytrain)*100
GradientBoostingtrain
# Out:
# 100.0

# %%
GradientBoostingtest=model5.score(xtest,ytest)*100
GradientBoostingtest
# Out:
# 95.33333333333334

# %% [markdown]
# ## KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
model6=KNeighborsClassifier(n_neighbors=5)
model6.fit(xtrain,ytrain)
print("Model trained Successfully")
# Out:
# Model trained Successfully

# %%
KNeighborstrain=model6.score(xtrain,ytrain)*100
KNeighborstrain
# Out:
# 87.14285714285714

# %%
KNeighborstest=model6.score(xtest,ytest)*100
KNeighborstest
# Out:
# 74.66666666666667

# %% [markdown]
# ## GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB
model7=GaussianNB()

# %%
model7.fit(xtrain,ytrain)
print("Model trained Successfully")
# Out:
# Model trained Successfully

# %%
Gaussiantrain=model7.score(xtrain,ytrain)*100
Gaussiantrain
# Out:
# 94.28571428571428

# %%
Gaussiantest=model7.score(xtest,ytest)*100
Gaussiantest
# Out:
# 88.66666666666667

# %% [markdown]
# # Prediction

# %%
Country=(input("Enter the Country"))
Country=obj.fit_transform([Country])
# Out:
# Enter the Country Japan

# %%
Year=int(input("Enter the Year"))
Year
# Out:
# Enter the Year 2024
# 2024

# %%
Total_Water_Consumption=float(input("Enter the Total Water Consumption"))
Total_Water_Consumption
# Out:
# Enter the Total Water Consumption 678
# 678.0

# %%
Per_Capita_Water_Use=float(input("Enter the Per Capita Water Use"))
Per_Capita_Water_Use
# Out:
# Enter the Per Capita Water Use 250
# 250.0

# %%
Agricultural_Water_Use=float(input("Enter the Agricultural Water Use"))
Agricultural_Water_Use
# Out:
# Enter the Agricultural Water Use 37
# 37.0

# %%
Industrial_Water_Use=float(input("Enter the Industrial Water Use "))
Industrial_Water_Use
# Out:
# Enter the Industrial Water Use  49
# 49.0

# %%
Household_Water_Use=float(input("Enter the Household Water Use"))
Household_Water_Use
# Out:
# Enter the Household Water Use 158
# 158.0

# %%
Rainfall_Impact=float(input("Enter the Rainfall Impact"))
Rainfall_Impact
# Out:
# Enter the Rainfall Impact 893
# 893.0

# %%
Groundwater_Depletion_Rate=float(input("Enter the Groundwater Depletion Rate"))
Groundwater_Depletion_Rate
# Out:
# Enter the Groundwater Depletion Rate 3.8
# 3.8

# %%
print(model4.predict([[Country[0],Year,Total_Water_Consumption,Per_Capita_Water_Use,Agricultural_Water_Use,Industrial_Water_Use,Household_Water_Use,Rainfall_Impact,Groundwater_Depletion_Rate]]))
# Out:
# ['Moderate']

# %% [markdown]
# # BUILD GRADIO INTERFACE

# %%
# !pip3 install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\chaithra s\anaconda3\lib\site-packages (6.17.3)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (4.10.0)
# Requirement already satisfied: audioop-lts<=0.2.2 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.136.3)
# Requirement already satisfied: gradio-client==2.5.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (2.5.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.4.1)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (1.18.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (2.3.5)
# Requirement already satisfied: orjson~=3.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (3.11.9)
# Requirement already satisfied: packaging in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (12.0.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (2.12.4)
# Requirement already satisfied: pydub<1.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.0.32)
# Requirement already satisfied: pytz>=2017.2 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=1.0.1 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (1.2.1)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio) (0.49.0)
# Requirement already satisfied: fsspec in c:\users\chaithra s\anaconda3\lib\site-packages (from gradio-client==2.5.0->gradio) (2025.10.0)
# Requirement already satisfied: idna>=2.8 in c:\users\chaithra s\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\chaithra s\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\chaithra s\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\chaithra s\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\users\chaithra s\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\chaithra s\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\chaithra s\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\chaithra s\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\chaithra s\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chaithra s\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chaithra s\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\chaithra s\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.41.5)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: colorama in c:\users\chaithra s\anaconda3\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=0.33.5->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\chaithra s\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\chaithra s\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\chaithra s\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
def fun(Country,Year,Total_Water_Consumption,Per_Capita_Water_Use,Agricultural_Water_Use,Industrial_Water_Use,Household_Water_Use,Rainfall_Impact,Groundwater_Depletion_Rate):
    Country = obj.fit_transform([Country])
    pred = model4.predict([[Country[0],Year,Total_Water_Consumption,Per_Capita_Water_Use,Agricultural_Water_Use,Industrial_Water_Use,Household_Water_Use,Rainfall_Impact,Groundwater_Depletion_Rate]])
    return pred

# %%
import gradio as gr

# %%
headline ="Water Scarcity Prediction App"
Countries = ['Argentina', 'Australia', 'Brazil', 'Canada', 'China', 'France',
       'Germany', 'India', 'Indonesia', 'Italy', 'Japan', 'Mexico',
       'Russia', 'Saudi Arabia', 'South Africa', 'South Korea', 'Spain',
       'Turkey', 'UK', 'USA']
iface = gr.Interface(fn=fun,inputs=[
        gr.Dropdown(choices=Countries,label="Country"),
        gr.Textbox(label="Year"),
        gr.Textbox(label="Total_Water_Consumption"),
        gr.Textbox(label="Per_Capita_Water_Use"),
        gr.Textbox(label="Agricultural_Water_Use"),
        gr.Textbox(label="Industrial_Water_Use"),
        gr.Textbox(label="Household_Water_Use"),
        gr.Textbox(label="Rainfall_Impact"),
        gr.Textbox(label="Groundwater_Depletion_Rate")],
        outputs=[gr.Textbox(label="Water Scarcity Level")],title=headline,css=".gradio-container {background-color:pink}")
iface.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://97ee78fbefe57b8dc5.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://97ee78fbefe57b8dc5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
